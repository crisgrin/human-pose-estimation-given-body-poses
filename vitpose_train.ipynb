# %%
# !rm -r sample_data/
# !wget http://images.cocodataset.org/zips/train2017.zip
# Out:
# --2022-06-09 13:16:27--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.154.236
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.154.236|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘train2017.zip’
#
# train2017.zip       100%[===================>]  18.01G  72.2MB/s    in 5m 21s
#
# 2022-06-09 13:21:48 (57.5 MB/s) - ‘train2017.zip’ saved [19336861798/19336861798]

# %%
#!unzip train2017.zip -d /content/ViTPose/data/coco
# !unzip train2017.zip

# %%
# !rm train2017.zip

# %%
# !git clone https://github.com/open-mmlab/mmcv.git
# Out:
# Cloning into 'mmcv'...
# remote: Enumerating objects: 11570, done.
# remote: Total 11570 (delta 0), reused 0 (delta 0), pack-reused 11570
# Receiving objects: 100% (11570/11570), 12.15 MiB | 35.06 MiB/s, done.
# Resolving deltas: 100% (8360/8360), done.

# %%
# !pip uninstall mmcv-full -y
# Out:
# WARNING: Skipping mmcv-full as it is not installed.

# %%
import torch
print(torch.__version__)
# !pip uninstall torch -y
# !pip uninstall torchvision -y
# !pip uninstall torchaudio -y
# Out:
# 1.11.0+cu113
# Found existing installation: torch 1.11.0+cu113
# Uninstalling torch-1.11.0+cu113:
#   Successfully uninstalled torch-1.11.0+cu113
# Found existing installation: torchvision 0.12.0+cu113
# Uninstalling torchvision-0.12.0+cu113:
#   Successfully uninstalled torchvision-0.12.0+cu113
# Found existing installation: torchaudio 0.11.0+cu113
# Uninstalling torchaudio-0.11.0+cu113:
#   Successfully uninstalled torchaudio-0.11.0+cu113

# %%
# !nvcc --version
# !pip install torch==1.9.1 torchvision==0.10.1 torchaudio==0.9.1
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 831.4 MB 6.5 kB/s
# ...
#      |████████████████████████████████| 22.1 MB 2.8 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 57.5 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.9.1 which is incompatible.
# ...

# %%
# !pip uninstall mmcv-full -y
# Out:
# Found existing installation: mmcv-full 1.3.16
# Uninstalling mmcv-full-1.3.16:
#   Successfully uninstalled mmcv-full-1.3.16

# %%
# !git clone https://github.com/open-mmlab/mmcv.git
# !cd mmcv && git checkout v1.3.9 && MMCV_WITH_OPS=1 pip install -e .
# Out:
# fatal: destination path 'mmcv' already exists and is not an empty directory.
# HEAD is now at 96c4b70 bump version to v1.3.9 (#1188)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/mmcv
# ...
#   Running setup.py develop for mmcv-full
# ...

# %%
#!MMCV_WITH_OPS=1 pip install -e ./mmcv
#!pip install mmcv-full==1.3.16 -f https://download.openmmlab.com/mmcv/dist/cu111/torch1.9.0/index.html
#!pip install mmcv-full==1.3.16 -f https://download.openmmlab.com/mmcv/dist/cu111/torch1.9.0/index.html
#!pip install mmcv-full==1.5 -f https://download.openmmlab.com/mmcv/dist/cpu/torch1.11.0/index.html

# %%
# !git clone https://github.com/ViTAE-Transformer/ViTPose.git
# !pip install -v -e ./ViTPose

# %%
# !pip install timm==0.4.9 einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 346 kB 7.9 MB/s
# ...

# %%
# Results from this repo on MS COCO val set (multi-task training)
# MODEL B
# !wget -O model_b.pth https://fd0rfg.sn.files.1drv.com/y4mjxZwPM-eGNFmXLsf91PehujeQMrrF_3u34fFj5aaZyJVLka85mkdL8CXELnZUv5dINCzwWk_gtuxjs5DSluasUcio_U1DRqNAnMFeaACjUuYq65nIV7UBzeutRE1OE2HYfkD79eXHaD-VR0r8txxAQot2TQOnafJgBfPQSxgMyak93Gt8_V7fr4WZFJbFy_fasyBRBl1OYh_jOr--167fQ
# Out:
# --2022-06-09 09:44:46--  https://fd0rfg.sn.files.1drv.com/y4mjxZwPM-eGNFmXLsf91PehujeQMrrF_3u34fFj5aaZyJVLka85mkdL8CXELnZUv5dINCzwWk_gtuxjs5DSluasUcio_U1DRqNAnMFeaACjUuYq65nIV7UBzeutRE1OE2HYfkD79eXHaD-VR0r8txxAQot2TQOnafJgBfPQSxgMyak93Gt8_V7fr4WZFJbFy_fasyBRBl1OYh_jOr--167fQ
# Resolving fd0rfg.sn.files.1drv.com (fd0rfg.sn.files.1drv.com)... 13.107.42.12
# Connecting to fd0rfg.sn.files.1drv.com (fd0rfg.sn.files.1drv.com)|13.107.42.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 360038314 (343M) [application/zip]
# Saving to: ‘model_b.pth’
#
# model_b.pth         100%[===================>] 343.36M  28.2MB/s    in 13s
#
# 2022-06-09 09:44:59 (27.4 MB/s) - ‘model_b.pth’ saved [360038314/360038314]

# %%
# Configs Model B
# !wget https://raw.githubusercontent.com/ViTAE-Transformer/ViTPose/main/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/coco/ViTPose_base_coco_256x192.py
# Out:
# --2022-06-09 09:44:59--  https://raw.githubusercontent.com/ViTAE-Transformer/ViTPose/main/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/coco/ViTPose_base_coco_256x192.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5220 (5.1K) [text/plain]
# Saving to: ‘ViTPose_base_coco_256x192.py’
#
# ViTPose_base_coco_2 100%[===================>]   5.10K  --.-KB/s    in 0s
#
# 2022-06-09 09:44:59 (75.9 MB/s) - ‘ViTPose_base_coco_256x192.py’ saved [5220/5220]

# %%
# !pip install apex

# %%
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2022-06-09 09:45:22--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 54.231.203.137
# Connecting to images.cocodataset.org (images.cocodataset.org)|54.231.203.137|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  96.4MB/s    in 2.5s
#
# 2022-06-09 09:45:25 (96.4 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]

# %%
# !cd ViTPose && mkdir data
# !cd ViTPose && mkdir coco
# !unzip annotations_trainval2017.zip -d ViTPose/data/coco
# Out:
# Archive:  annotations_trainval2017.zip
#   inflating: ViTPose/data/coco/annotations/instances_train2017.json
#   inflating: ViTPose/data/coco/annotations/instances_val2017.json
#   inflating: ViTPose/data/coco/annotations/captions_train2017.json
#   inflating: ViTPose/data/coco/annotations/captions_val2017.json
#   inflating: ViTPose/data/coco/annotations/person_keypoints_train2017.json
#   inflating: ViTPose/data/coco/annotations/person_keypoints_val2017.json

# %%
# !wget http://images.cocodataset.org/annotations/stuff_annotations_trainval2017.zip
# !unzip stuff_annotations_trainval2017.zip -d ViTPose/data/coco

# %%
# !wget http://images.cocodataset.org/annotations/panoptic_annotations_trainval2017.zip
# !unzip panoptic_annotations_trainval2017.zip -d ViTPose/data/coco

# %%
# !unzip person_detection_results.zip -d /content/ViTPose/data/coco
# Out:
# Archive:  person_detection_results.zip
#   inflating: /content/ViTPose/data/coco/person_detection_results/COCO_val2017_detections_AP_H_56_person.json
#   inflating: /content/ViTPose/data/coco/person_detection_results/COCO_test-dev2017_detections_AP_H_609_person.json

# %%
# !mv train2017 ViTPose/data/coco

# %%
# Go in the settings file ViTPose_base_coco_256x192.py and change the paths at the beginning to:
# /content/ViTPose/configs/_base_/.....

# !cd ViTPose && bash tools/dist_train.sh ../ViTPose_base_coco_256x192.py 1 --cfg-options model.pretrained=../model_b.pth --seed 0
