# %%
from google.colab import files
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New section

# %%
# !wget -O annotation_image_info.json https://zenodo.org/record/1059155/files/annotation_image_info.json?download=1
# Out:
# --2022-06-11 10:09:37--  https://zenodo.org/record/1059155/files/annotation_image_info.json?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3988574 (3.8M) [text/plain]
# Saving to: ‘annotation_image_info.json’
#
# annotation_image_in 100%[===================>]   3.80M  22.5MB/s    in 0.2s
#
# 2022-06-11 10:09:39 (22.5 MB/s) - ‘annotation_image_info.json’ saved [3988574/3988574]

# %%
# !wget -O domain.json https://zenodo.org/record/1059155/files/domain.json?download=1
# Out:
# --2022-06-11 10:08:39--  https://zenodo.org/record/1059155/files/domain.json?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1013122 (989K) [text/plain]
# Saving to: ‘domain.json’
#
# domain.json         100%[===================>] 989.38K  --.-KB/s    in 0.1s
#
# 2022-06-11 10:08:40 (9.99 MB/s) - ‘domain.json’ saved [1013122/1013122]

# %%
# !wget -O domain_split.zip https://zenodo.org/record/1059155/files/domain_split.zip?download=1
# Out:
# --2022-06-11 10:09:14--  https://zenodo.org/record/1059155/files/domain_split.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57283 (56K) [application/octet-stream]
# Saving to: ‘domain_split.zip’
#
# domain_split.zip    100%[===================>]  55.94K  --.-KB/s    in 0.02s
#
# 2022-06-11 10:09:15 (2.78 MB/s) - ‘domain_split.zip’ saved [57283/57283]

# %%
# !wget -O images-00 https://zenodo.org/record/1059155/files/images-00?download=1
# Out:
# --2022-06-11 10:11:29--  https://zenodo.org/record/1059155/files/images-00?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1024000000 (977M) [application/octet-stream]
# Saving to: ‘images-00’
#
# images-00           100%[===================>] 976.56M   132MB/s    in 7.6s
#
# 2022-06-11 10:11:37 (128 MB/s) - ‘images-00’ saved [1024000000/1024000000]

# %%
# !wget -O images-01 https://zenodo.org/record/1059155/files/images-01?download=1
# Out:
# --2022-06-11 10:11:38--  https://zenodo.org/record/1059155/files/images-01?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1024000000 (977M) [application/octet-stream]
# Saving to: ‘images-01’
#
# images-01           100%[===================>] 976.56M  70.5MB/s    in 11s
#
# 2022-06-11 10:11:50 (88.7 MB/s) - ‘images-01’ saved [1024000000/1024000000]

# %%
# !wget -O images-02 https://zenodo.org/record/1059155/files/images-02?download=1
# Out:
# --2022-06-11 10:11:50--  https://zenodo.org/record/1059155/files/images-02?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1024000000 (977M) [application/octet-stream]
# Saving to: ‘images-02’
#
# images-02           100%[===================>] 976.56M  61.6MB/s    in 10s
#
# 2022-06-11 10:12:01 (97.7 MB/s) - ‘images-02’ saved [1024000000/1024000000]

# %%
# !wget -O images-03 https://zenodo.org/record/1059155/files/images-03?download=1
# Out:
# --2022-06-11 10:12:01--  https://zenodo.org/record/1059155/files/images-03?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 646349112 (616M) [application/octet-stream]
# Saving to: ‘images-03’
#
# images-03           100%[===================>] 616.41M  71.3MB/s    in 8.9s
#
# 2022-06-11 10:12:11 (69.4 MB/s) - ‘images-03’ saved [646349112/646349112]

# %%
# !wget -O occupation.json https://zenodo.org/record/1059155/files/occupation.json?download=1
# Out:
# --2022-06-11 10:12:12--  https://zenodo.org/record/1059155/files/occupation.json?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 899114 (878K) [text/plain]
# Saving to: ‘occupation.json’
#
# occupation.json     100%[===================>] 878.04K  --.-KB/s    in 0.09s
#
# 2022-06-11 10:12:13 (9.10 MB/s) - ‘occupation.json’ saved [899114/899114]

# %%
# !wget -O relationship.json https://zenodo.org/record/1059155/files/relationship.json?download=1
# Out:
# --2022-06-11 10:12:45--  https://zenodo.org/record/1059155/files/relationship.json?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 804238 (785K) [text/plain]
# Saving to: ‘relationship.json’
#
# relationship.json   100%[===================>] 785.39K  --.-KB/s    in 0.1s
#
# 2022-06-11 10:12:46 (6.40 MB/s) - ‘relationship.json’ saved [804238/804238]

# %%
# !wget -O relationship_split.zip https://zenodo.org/record/1059155/files/relationship_split.zip?download=1
# Out:
# --2022-06-11 10:13:25--  https://zenodo.org/record/1059155/files/relationship_split.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49884 (49K) [application/octet-stream]
# Saving to: ‘relationship_split.zip’
#
# relationship_split. 100%[===================>]  48.71K  --.-KB/s    in 0.02s
#
# 2022-06-11 10:13:26 (2.46 MB/s) - ‘relationship_split.zip’ saved [49884/49884]

# %%
# !cp annotation_image_info.json "/content/drive/My Drive/AdvancedComputerVision"
# !cp domain.json "/content/drive/My Drive/AdvancedComputerVision"
# !cp domain_split.zip "/content/drive/My Drive/AdvancedComputerVision"
# !cp images-00 "/content/drive/My Drive/AdvancedComputerVision"
# !cp images-01 "/content/drive/My Drive/AdvancedComputerVision"
# !cp images-02 "/content/drive/My Drive/AdvancedComputerVision"
# !cp images-03 "/content/drive/My Drive/AdvancedComputerVision"
# !cp occupation.json "/content/drive/My Drive/AdvancedComputerVision"
# !cp relationship.json "/content/drive/My Drive/AdvancedComputerVision"
# !cp relationship_split.zip "/content/drive/My Drive/AdvancedComputerVision"
# Out:
# cp: cannot stat 'relationship_split.json': No such file or directory

# %%
# !cat '/content/drive/My Drive/AdvancedComputerVision/'images-* | tar zx

# %%
# !cp -r image '/content/drive/My Drive/AdvancedComputerVision/'

# %%
drive.flush_and_unmount()
